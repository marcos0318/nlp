# %%
""" test the tensorflow environment"""
import numpy as np
import tensorflow as tf
hello = tf.constant('Hello, TensorFlow!')
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!'

# %%
# import regular expression to remove the tags from the wiki extractor
import re
# import os to read iterating through the files
import os

def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', raw_html)
    return cleantext


def line_reader(dirname):
    counter = 0
    for root, dirs, files in os.walk(dirname):
        for filename in files:
            file_path = root+'\\'+filename
            print (file_path)
            for line in open(file_path,'r',encoding='UTF-8'):
                counter += 1
                
                sline = line.strip()
                if sline == "":
                    continue
                rline = cleanhtml(sline).strip()
                if rline == "":
                    continue
                # print(rline)
                    
                word_line = [word for word in rline.lower().split()]
                yield word_line
            # print (counter)

reader = line_reader("enwiki")

# Line number AA to AC: 1196943
for i in range(700000):
    next(reader)
# 哈哈哈哈
# Out:
# enwiki\AA\wiki_00
# enwiki\AA\wiki_01
# enwiki\AA\wiki_02
# enwiki\AA\wiki_03
# enwiki\AA\wiki_04
# enwiki\AA\wiki_05
# enwiki\AA\wiki_06
# enwiki\AA\wiki_07
# enwiki\AA\wiki_08
# enwiki\AA\wiki_09
# enwiki\AA\wiki_10
# enwiki\AA\wiki_11
# enwiki\AA\wiki_12
# enwiki\AA\wiki_13
# enwiki\AA\wiki_14
# enwiki\AA\wiki_15
# enwiki\AA\wiki_16
# enwiki\AA\wiki_17
# enwiki\AA\wiki_18
# enwiki\AA\wiki_19
# enwiki\AA\wiki_20
# enwiki\AA\wiki_21
# enwiki\AA\wiki_22
# enwiki\AA\wiki_23
# enwiki\AA\wiki_24
# enwiki\AA\wiki_25
# enwiki\AA\wiki_26
# enwiki\AA\wiki_27
# enwiki\AA\wiki_28
# enwiki\AA\wiki_29
# enwiki\AA\wiki_30
# enwiki\AA\wiki_31
# enwiki\AA\wiki_32
# enwiki\AA\wiki_33
# enwiki\AA\wiki_34
# enwiki\AA\wiki_35
# enwiki\AA\wiki_36
# enwiki\AA\wiki_37
# enwiki\AA\wiki_38
# enwiki\AA\wiki_39
# enwiki\AA\wiki_40
# enwiki\AA\wiki_41
# enwiki\AA\wiki_42
# enwiki\AA\wiki_43
# enwiki\AA\wiki_44
# enwiki\AA\wiki_45
# enwiki\AA\wiki_46
# enwiki\AA\wiki_47
# enwiki\AA\wiki_48
# enwiki\AA\wiki_49
# ...

# %%
# use generator object 
def getInt():
    s = 0
    for i in range(10):
        yield s
        s += 1

t = getInt()

print(t)

# it is very hard to read the data that is stored in the file system. so we need to have a iterator to do this
print(next(t))
print(next(t))
print(next(t))
print(next(t))

# %%
import matplotlib.pyplot as plt
